# %%
# A set is a collection which is unordered, unchangeable*, and unindexed.

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset,type(thisset))
# Out:
# {'cherry', 'apple', 'banana'} <class 'set'>

# %%
thisset = {"apple", "banana", "cherry", "apple"}

print(thisset)
# Out:
# {'cherry', 'apple', 'banana'}

# %%
thisset = {"apple", "banana", "cherry", True, 1, 2,"1"}

print(thisset) # True and 1 considered as same value
# Out:
# {'cherry', 2, True, '1', 'apple', 'banana'}

# %%
len(thisset)
# Out:
# 6

# %%
thisset = {"apple", "banana", "cherry"}
thisset.add("aman")

print(thisset)
# Out:
# {'aman', 'cherry', 'apple', 'banana'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset,len(thisset))
# Out:
# {'cherry', 'pineapple', 'papaya', 'apple', 'mango', 'banana'} 6

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'cherry', 'orange', 'apple', 'banana', 'kiwi'}

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ("kiwi", "orange")

thisset.update(mylist)

print(thisset,type(thisset),type(mylist),len(thisset))
# Out:
# {'cherry', 'orange', 'apple', 'banana', 'kiwi'} <class 'set'> <class 'tuple'> 5

# %%
thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

x = thisset.pop() # remove a random item from set

print(x)

print(thisset)
# Out:
# cherry
# {'apple', 'banana'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.clear()

print(thisset)
# Out:
# set()

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3,"a"}
print(set1.union(set2))
print(set2.union(set1))
# Out:
# {1, 2, 3, 'a', 'b', 'c'}
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1 | set2
set3 = set2 | set1
print(set3)
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {1, 2, 3, 'cherry', 'a', 'b', 'apple', 'bananas', 'John', 'c', 'Elena'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
print(set1.intersection(set2))
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 & set2
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2) # eep ONLY the duplicates, but it will change the original set instead of returning a new set.

print(set1)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2) # The difference() method will return a new set that will contain only the items from the first set that are not present in the other set.

print(set3)
print(set2.difference(set1))
# Out:
# {'cherry', 'banana'}
# {'google', 'microsoft'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 - set2
print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.difference_update(set2)

print(set1)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2) # The symmetric_difference() method will keep only the elements that are NOT present in both sets.

print(set3)
# Out:
# {'cherry', 'microsoft', 'banana', 'google'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 ^ set2
print(set3)
# Out:
# {'cherry', 'microsoft', 'banana', 'google'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.symmetric_difference_update(set2)

print(set1)
# Out:
# {'cherry', 'microsoft', 'banana', 'google'}

# %% [markdown]
# ## **frozenset**

# %%
# frozenset is an immutable version of a set.

# Like sets, it contains unique, unordered, unchangeable elements.

# Unlike sets, elements cannot be added or removed from a frozenset.

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'cherry', 'apple', 'banana'})
# <class 'frozenset'>
