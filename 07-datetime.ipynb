# %%
print('radha')
# Out:
# radha

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 12, 12, 13, 3, 9, 553749)

# %%
import datetime

x = datetime.datetime.now()

print(x.year)
print(x.strftime("%A"))
# Out:
# 2025
# Friday

# %%
price = 49
txt = "The price is {} dollars"
print(txt)
print(txt.format(price))
# Out:
# The price is {} dollars
# The price is 49 dollars

# %%
import cowsay

cowsay.cow("Good Mooooorning!")
# Out:
#   _________________
# | Good Mooooorning! |
#   =================
#                  \
#                   \
#                     ^__^
#                     (oo)\_______
#                     (__)\       )\/\
#                         ||----w |
#                         ||     ||

# %%
cowsay.dragon("Good Mooooorning!")
# Out:
#   _________________
# | Good Mooooorning! |
#   =================
#                    \
#                     \
#                      \
#                       \
#                                             / \\  //\\
#                              |\\___/|      /   \\//  \\\\
#                              /0  0  \\__  /    //  | \\ \\
#                             /     /  \\/_/    //   |  \\  \\
#                             \@_^_\@'/   \\/_   //    |   \\   \\
#                             //_^_/     \\/_ //     |    \\    \\
#                          ( //) |        \\///      |     \\     \\
#                        ( / /) _|_ /   )  //       |      \\     _\\
#                      ( // /) '/,_ _ _/  ( ; -.    |    _ _\\.-~        .-~~~^-.
#                    (( / / )) ,-{        _      `-.|.-~-.           .~         `.
#                   (( // / ))  '/\\      /                 ~-. _ .-~      .-~^-.  \\
#                   (( /// ))      `.   {            }                   /      \\  \\
#                    (( / ))     .----~-.\\        \\-'                 .~         \\  `. \\^-.
#                               ///.----..>        \\             _ -~             `.  ^-`  ^-_
#                                 ///-._ _ _ _ _ _ _}^ - - - - ~                     ~-- ,.-~
#                                                                                    /.-~

# %%
cowsay.octopus("aman")
# Out:
#   ____
# | aman |
#   ====
#          \
#           \
#            \
#                             . . .
#                           .   ^   .
#                          .  ^ ^ ^  .
#                          .  ^ ^ ^  .
#                           .   ^    .
#                             . . .
#               _ _ _ _ _ _ _|     |_ _ _ _ _ _
#              /  _ _ _ _ _ _| o|o |_ _ _ _ _ _ \
#             / /  _ _ _  _ _|  |  |_ _ _ _    \ \
#            / /  /  _ _ _ / /| |\ \ _ _ _  \   \ \
#           / /  /  /     / / | | \ \     \  \   \ \
#          / /  /  /     / /  | |  \ \     \  \   \ \
#         /_/  /  /     / /   | |   \ \     \  \   \_\
#          |  /__/     /_/    |_|    \_\     \__\   |
#               |      /       |       \       |
