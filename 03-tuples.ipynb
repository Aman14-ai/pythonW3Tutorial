# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple,type(thistuple),len(thistuple))
# Out:
# ('apple', 'banana', 'cherry') <class 'tuple'> 3

# %%
thistuple = ("apple",) # remember this comma
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
tuple1 = ("abc", 34, True, 40, "male")
print(tuple1,type(tuple1))
# Out:
# ('abc', 34, True, 40, 'male') <class 'tuple'>

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[-1])
# Out:
# cherry

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[:4])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %% [markdown]
# **Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.**
#
# **But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple.**

# %%
x = ("apple", "banana", "cherry")
y = list(x)
print(x,type(x))
print(y,type(y))
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'banana', 'cherry') <class 'tuple'>
# ['apple', 'banana', 'cherry'] <class 'list'>
# ('apple', 'kiwi', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)

# %% [markdown]
# ### **unpacking**

# %%
fruits = ("apple", "banana", "cherry")

green, yellow,_ = fruits
print(green,yellow)
# Out:
# apple banana

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits

print(green,type(green))
print(yellow)
print(red,type(red))
# Out:
# apple <class 'str'>
# banana
# ['cherry', 'strawberry', 'raspberry'] <class 'list'>

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

(green, *tropic, red) = fruits

print(green)
print(tropic)
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %%
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2

print(mytuple)
mytuple = fruits+fruits
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
#Tuples exist in Python because they serve purposes that lists cannot, especially in areas of safety, performance, and semantics.
# A list is not a universal substitute for a tuple.

# 2. Tuples Can Be Dictionary Keys (Lists Cannot)

# Because tuples are immutable, they are hashable.
coords = {}
coords[(10, 20)] = "tree"

print(coords[(10, 20)])
# Out:
# tree

# %%
coords[[10, 20]] = "tree"  # TypeError: unhashable type: 'list'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 coords[[10, 20]] = "tree"  # TypeError: unhashable type: 'list'
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
# Tuples require less memory and fewer operations.

# %%
#Tuples represent records, similar to a row in a database or struct in C.
student = ("Aman", 21, "CSE")

# %%
def divide(a, b):
    return (a // b, a % b)

q, r = divide(10, 3)
q,r
# Out:
# (3, 1)
